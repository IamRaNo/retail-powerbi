# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Rano's PC\Machine\💻data-science-projects\retail-dataset\superstore_sales.csv")

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
data.select_dtypes(include='number').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Row ID       9800 non-null   int64
#  1   Postal Code  9789 non-null   float64
#  2   Sales        9800 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 229.8 KB

# %%
data.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
data[['Customer ID','Product ID','Order ID']].nunique()
# Out:
# Customer ID     793
# Product ID     1861
# Order ID       4922
# dtype: int64

# %%
data[data.duplicated(subset=['Order ID', 'Product ID'], keep=False)].head()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 350      351  CA-2017-129714  01/09/2017  03/09/2017     First Class
# 352      353  CA-2017-129714  01/09/2017  03/09/2017     First Class
# 430      431  US-2017-123750  15/04/2017  21/04/2017  Standard Class
# 431      432  US-2017-123750  15/04/2017  21/04/2017  Standard Class
# 1300    1301  CA-2017-137043  23/12/2017  25/12/2017    Second Class
#
#      Customer ID    Customer Name      Segment        Country           City  \
# 350     AB-10060  Adam Bellavance  Home Office  United States  New York City
# 352     AB-10060  Adam Bellavance  Home Office  United States  New York City
# 430     RB-19795       Ross Baird  Home Office  United States       Gastonia
# 431     RB-19795       Ross Baird  Home Office  United States       Gastonia
# 1300    LC-17140     Logan Currie     Consumer  United States    Springfield
#
#                State  Postal Code Region       Product ID         Category  \
# ...

# %%
data=data.groupby(['Order ID', 'Product ID'], as_index=False).agg({
    'Customer ID': 'first',
    # Add any other columns you want to keep logically (optional):
    'Order Date': 'first',
    'Ship Date': 'first',
    'Row ID' : 'first',
    'Customer Name': 'first',
    'Segment': 'first',
    'Country': 'first',
    'City': 'first',
    'State': 'first',
    'Postal Code': 'first',
    'Region': 'first',
    'Product Name': 'first',
    'Category': 'first',
    'Sub-Category': 'first',
    'Ship Mode': 'first',
    'Sales': 'sum'
})

# %%
data[data.duplicated(subset=['Order ID', 'Product ID'], keep=False)].head()
# Out:
# Empty DataFrame
# Columns: [Order ID, Product ID, Customer ID, Order Date, Ship Date, Row ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product Name, Category, Sub-Category, Ship Mode, Sales]
# Index: []

# %%
data.columns=data.columns.str.lower()

# %%
data.columns
# Out:
# Index(['order id', 'product id', 'customer id', 'order date', 'ship date',
#        'row id', 'customer name', 'segment', 'country', 'city', 'state',
#        'postal code', 'region', 'product name', 'category', 'sub-category',
#        'ship mode', 'sales'],
#       dtype='object')

# %%
data.drop(columns='row id',inplace=True)

# %%
data.head(5)
# Out:
#          order id       product id customer id  order date   ship date  \
# 0  CA-2015-100006  TEC-PH-10002075    DK-13375  07/09/2015  13/09/2015
# 1  CA-2015-100090  FUR-TA-10003715    EB-13705  08/07/2015  12/07/2015
# 2  CA-2015-100090  OFF-BI-10001597    EB-13705  08/07/2015  12/07/2015
# 3  CA-2015-100293  OFF-PA-10000176    NF-18475  14/03/2015  18/03/2015
# 4  CA-2015-100328  OFF-BI-10000343    JC-15340  28/01/2015  03/02/2015
#
#       customer name      segment        country           city       state  \
# 0       Dennis Kane     Consumer  United States  New York City    New York
# 1        Ed Braxton    Corporate  United States  San Francisco  California
# 2        Ed Braxton    Corporate  United States  San Francisco  California
# 3  Neil Französisch  Home Office  United States   Jacksonville     Florida
# 4   Jasper Cacioppo     Consumer  United States  New York City    New York
#
#    postal code region                                       product name  \
# ...

# %%
data.describe()
# Out:
#         postal code         sales
# count   9781.000000   9792.000000
# mean   55289.480728    230.957596
# std    32044.254104    627.082820
# min     1040.000000      0.444000
# 25%    23223.000000     17.235000
# 50%    58103.000000     54.432000
# 75%    90008.000000    210.568000
# max    99301.000000  22638.480000

# %%
data['order date'].value_counts()
# Out:
# order date
# 05/09/2017    38
# 10/11/2017    35
# 01/12/2018    34
# 02/12/2018    34
# 09/12/2018    33
#               ..
# 13/09/2018     1
# 05/08/2017     1
# 28/01/2015     1
# 06/12/2018     1
# 25/11/2016     1
# Name: count, Length: 1230, dtype: int64

# %%
data['ship date'].value_counts()
# Out:
# ship date
# 26/09/2018    34
# 16/12/2016    31
# 06/12/2018    31
# 06/09/2018    30
# 15/09/2018    30
#               ..
# 16/12/2018     1
# 08/01/2018     1
# 15/02/2018     1
# 07/06/2016     1
# 05/06/2017     1
# Name: count, Length: 1326, dtype: int64

# %%
data['order date']=pd.to_datetime(data['order date'],dayfirst=True,errors='coerce')

# %%
data['ship date']=pd.to_datetime(data['ship date'],dayfirst=True,errors='coerce')

# %%
data['ship date']=pd.to_datetime(data['ship date'],format='mixed')

# %%
(data['ship date']-data['order date']).dt.days.value_counts()
# Out:
# 4    2715
# 5    2147
# 2    1293
# 6    1169
# 3     976
# 7     615
# 0     514
# 1     363
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#                           order date                      ship date  \
# count                           9792                           9792
# mean   2017-05-01 04:13:14.117647104  2017-05-05 03:17:47.647058944
# min              2015-01-03 00:00:00            2015-01-07 00:00:00
# 25%              2016-05-23 18:00:00            2016-05-27 00:00:00
# 50%              2017-06-26 00:00:00            2017-06-29 00:00:00
# 75%              2018-05-15 00:00:00            2018-05-19 00:00:00
# max              2018-12-30 00:00:00            2019-01-05 00:00:00
# std                              NaN                            NaN
#
#         postal code         sales
# count   9781.000000   9792.000000
# mean   55289.480728    230.957596
# min     1040.000000      0.444000
# 25%    23223.000000     17.235000
# 50%    58103.000000     54.432000
# 75%    90008.000000    210.568000
# max    99301.000000  22638.480000
# std    32044.254104    627.082820

# %%
data['state']
# Out:
# 0           New York
# 1         California
# 2         California
# 3            Florida
# 4           New York
#             ...
# 9787    Pennsylvania
# 9788    Pennsylvania
# 9789    Pennsylvania
# 9790    Pennsylvania
# 9791    Pennsylvania
# Name: state, Length: 9792, dtype: object

# %%
data.head()
# Out:
#          order id       product id customer id order date  ship date  \
# 0  CA-2015-100006  TEC-PH-10002075    DK-13375 2015-09-07 2015-09-13
# 1  CA-2015-100090  FUR-TA-10003715    EB-13705 2015-07-08 2015-07-12
# 2  CA-2015-100090  OFF-BI-10001597    EB-13705 2015-07-08 2015-07-12
# 3  CA-2015-100293  OFF-PA-10000176    NF-18475 2015-03-14 2015-03-18
# 4  CA-2015-100328  OFF-BI-10000343    JC-15340 2015-01-28 2015-02-03
#
#       customer name      segment        country           city       state  \
# 0       Dennis Kane     Consumer  United States  New York City    New York
# 1        Ed Braxton    Corporate  United States  San Francisco  California
# 2        Ed Braxton    Corporate  United States  San Francisco  California
# 3  Neil Französisch  Home Office  United States   Jacksonville     Florida
# 4   Jasper Cacioppo     Consumer  United States  New York City    New York
#
#    postal code region                                       product name  \
# ...

# %%
data.groupby('customer id')['customer name'].nunique().value_counts()

# Step 2: Filter those with more than 1 unique name
#conflicting_ids = mismatch_ids[mismatch_ids > 1]
# Out:
# customer name
# 1    793
# Name: count, dtype: int64

# %%
data.groupby('product id')['product name'].nunique().value_counts()
# Out:
# product name
# 1    1829
# 2      32
# Name: count, dtype: int64

# %%
mismatch_ids = data.groupby('product id')['product name'].nunique()

# Step 2: Filter those with more than 1 unique name
conflicting_ids = mismatch_ids[mismatch_ids > 1]

# %%
conflicting_ids
# Out:
# product id
# FUR-BO-10002213    2
# FUR-CH-10001146    2
# FUR-FU-10001473    2
# FUR-FU-10004017    2
# FUR-FU-10004091    2
# FUR-FU-10004270    2
# FUR-FU-10004848    2
# FUR-FU-10004864    2
# OFF-AP-10000576    2
# OFF-AR-10001149    2
# OFF-BI-10002026    2
# OFF-BI-10004632    2
# OFF-BI-10004654    2
# OFF-PA-10000357    2
# OFF-PA-10000477    2
# OFF-PA-10000659    2
# OFF-PA-10001166    2
# OFF-PA-10001970    2
# OFF-PA-10002195    2
# OFF-PA-10002377    2
# OFF-PA-10003022    2
# OFF-ST-10001228    2
# OFF-ST-10004950    2
# TEC-AC-10002049    2
# TEC-AC-10002550    2
# TEC-AC-10003832    2
# TEC-MA-10001148    2
# TEC-PH-10001530    2
# TEC-PH-10001795    2
# TEC-PH-10002200    2
# TEC-PH-10002310    2
# TEC-PH-10004531    2
# Name: product name, dtype: int64

# %%
pd.set_option("display.max_rows",1000)

# %%
if not conflicting_ids.empty:
    conflict_details = data[data['product id'].isin(conflicting_ids.index)][['product id', 'product name']].drop_duplicates()
    print("\nConflict Details:")
    print(conflict_details.sort_values(by='product id'))
# Out:
# Conflict Details:
#            product id                                       product name
# 627   FUR-BO-10002213              DMI Eclipse Executive Suite Bookcases
# 2919  FUR-BO-10002213   Sauder Forest Hills Library, Woodland Oak Finish
# 4771  FUR-CH-10001146                           Global Task Chair, Black
# 263   FUR-CH-10001146        Global Value Mid-Back Manager's Chair, Gray
# 2399  FUR-FU-10001473  Eldon Executive Woodline II Desk Accessories, ...
# 1302  FUR-FU-10001473                            DAX Wood Document Frame
# 1631  FUR-FU-10004017      Executive Impressions 13" Chairman Wall Clock
# 2619  FUR-FU-10004017  Tenex Contemporary Contur Chairmats for Low an...
# 295   FUR-FU-10004091  Howard Miller 13" Diameter Goldtone Round Wall...
# 81    FUR-FU-10004091            Eldon 200 Class Desk Accessories, Black
# 328   FUR-FU-10004270      Eldon Image Series Desk Accessories, Burgundy
# 773   FUR-FU-10004270     Executive Impressions 13" Clairmont Wall Clock
# ...

# %%
data.head()
# Out:
#          order id       product id customer id order date  ship date  \
# 0  CA-2015-100006  TEC-PH-10002075    DK-13375 2015-09-07 2015-09-13
# 1  CA-2015-100090  FUR-TA-10003715    EB-13705 2015-07-08 2015-07-12
# 2  CA-2015-100090  OFF-BI-10001597    EB-13705 2015-07-08 2015-07-12
# 3  CA-2015-100293  OFF-PA-10000176    NF-18475 2015-03-14 2015-03-18
# 4  CA-2015-100328  OFF-BI-10000343    JC-15340 2015-01-28 2015-02-03
#
#       customer name      segment        country           city       state  \
# 0       Dennis Kane     Consumer  United States  New York City    New York
# 1        Ed Braxton    Corporate  United States  San Francisco  California
# 2        Ed Braxton    Corporate  United States  San Francisco  California
# 3  Neil Französisch  Home Office  United States   Jacksonville     Florida
# 4   Jasper Cacioppo     Consumer  United States  New York City    New York
#
#    postal code region                                       product name  \
# ...

# %%
data[data['postal code'].isnull()]
# Out:
#             order id       product id customer id order date  ship date  \
# 2093  CA-2016-117086  FUR-BO-10004834    QJ-19255 2016-11-08 2016-11-12
# 3237  CA-2016-162887  FUR-CH-10000595    SV-20785 2016-11-07 2016-11-09
# 5664  CA-2018-104066  TEC-AC-10001013    QJ-19255 2018-12-05 2018-12-10
# 9085  US-2017-150140  TEC-PH-10002555    VM-21685 2017-04-06 2017-04-10
# 9184  US-2017-165505  OFF-AR-10003477    CB-12535 2017-01-23 2017-01-27
# 9185  US-2017-165505  OFF-ST-10001526    CB-12535 2017-01-23 2017-01-27
# 9186  US-2017-165505  TEC-AC-10002926    CB-12535 2017-01-23 2017-01-27
# 9470  US-2018-127292  OFF-AP-10000828    RM-19375 2018-01-19 2018-01-23
# 9471  US-2018-127292  OFF-EN-10001509    RM-19375 2018-01-19 2018-01-23
# 9472  US-2018-127292  OFF-PA-10000157    RM-19375 2018-01-19 2018-01-23
# 9473  US-2018-127292  OFF-PA-10001970    RM-19375 2018-01-19 2018-01-23
#
#          customer name      segment        country        city    state  \
# ...

# %%
data[data['city']=='Burlington']
# Out:
#             order id       product id customer id order date  ship date  \
# 2093  CA-2016-117086  FUR-BO-10004834    QJ-19255 2016-11-08 2016-11-12
# 3237  CA-2016-162887  FUR-CH-10000595    SV-20785 2016-11-07 2016-11-09
# 4302  CA-2017-130820  FUR-TA-10001768    ON-18715 2017-11-15 2017-11-15
# 5664  CA-2018-104066  TEC-AC-10001013    QJ-19255 2018-12-05 2018-12-10
# 6348  CA-2018-121818  OFF-AR-10000203    JH-15430 2018-11-20 2018-11-21
# 6349  CA-2018-121818  OFF-AR-10004790    JH-15430 2018-11-20 2018-11-21
# 6480  CA-2018-124828  OFF-AR-10003514    YS-21880 2018-07-03 2018-07-04
# 6704  CA-2018-130904  OFF-AR-10000127    HM-14980 2018-04-11 2018-04-16
# 6705  CA-2018-130904  OFF-AR-10000422    HM-14980 2018-04-11 2018-04-16
# 7146  CA-2018-142090  FUR-TA-10001889    SC-20380 2018-11-30 2018-12-07
# 7147  CA-2018-142090  TEC-AC-10002001    SC-20380 2018-11-30 2018-12-07
# 7168  CA-2018-142776  OFF-BI-10002012    RS-19870 2018-12-11 2018-12-14
# ...

# %%
data['postal code'].fillna(5401,inplace=True)
# Out:
# C:\Users\Rano's PC\AppData\Local\Temp\ipykernel_3960\2237648615.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['postal code'].fillna(5401,inplace=True)

# %%
data['postal code']=data['postal code'].astype(float).astype(int).astype(str)

# %%
data['postal code']=data['postal code'].str.replace('5401','05401')

# %%
data['sales']=data['sales'].round(2)

# %%
data.head()
# Out:
#          order id       product id customer id order date  ship date  \
# 0  CA-2015-100006  TEC-PH-10002075    DK-13375 2015-09-07 2015-09-13
# 1  CA-2015-100090  FUR-TA-10003715    EB-13705 2015-07-08 2015-07-12
# 2  CA-2015-100090  OFF-BI-10001597    EB-13705 2015-07-08 2015-07-12
# 3  CA-2015-100293  OFF-PA-10000176    NF-18475 2015-03-14 2015-03-18
# 4  CA-2015-100328  OFF-BI-10000343    JC-15340 2015-01-28 2015-02-03
#
#       customer name      segment        country           city       state  \
# 0       Dennis Kane     Consumer  United States  New York City    New York
# 1        Ed Braxton    Corporate  United States  San Francisco  California
# 2        Ed Braxton    Corporate  United States  San Francisco  California
# 3  Neil Französisch  Home Office  United States   Jacksonville     Florida
# 4   Jasper Cacioppo     Consumer  United States  New York City    New York
#
#   postal code region                                       product name  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9792 entries, 0 to 9791
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order id       9792 non-null   object
#  1   product id     9792 non-null   object
#  2   customer id    9792 non-null   object
#  3   order date     9792 non-null   datetime64[ns]
#  4   ship date      9792 non-null   datetime64[ns]
#  5   customer name  9792 non-null   object
#  6   segment        9792 non-null   object
#  7   country        9792 non-null   object
#  8   city           9792 non-null   object
#  9   state          9792 non-null   object
#  10  postal code    9792 non-null   object
#  11  region         9792 non-null   object
#  12  product name   9792 non-null   object
#  13  category       9792 non-null   object
#  14  sub-category   9792 non-null   object
#  15  ship mode      9792 non-null   object
#  16  sales          9792 non-null   float64
# ...

# %%
data['country'].value_counts()
# Out:
# country
# United States    9792
# Name: count, dtype: int64

# %%
data.drop('country',axis=1,inplace=True)

# %%
data.head()
# Out:
#          order id       product id customer id order date  ship date  \
# 0  CA-2015-100006  TEC-PH-10002075    DK-13375 2015-09-07 2015-09-13
# 1  CA-2015-100090  FUR-TA-10003715    EB-13705 2015-07-08 2015-07-12
# 2  CA-2015-100090  OFF-BI-10001597    EB-13705 2015-07-08 2015-07-12
# 3  CA-2015-100293  OFF-PA-10000176    NF-18475 2015-03-14 2015-03-18
# 4  CA-2015-100328  OFF-BI-10000343    JC-15340 2015-01-28 2015-02-03
#
#       customer name      segment           city       state postal code  \
# 0       Dennis Kane     Consumer  New York City    New York       10024
# 1        Ed Braxton    Corporate  San Francisco  California       94122
# 2        Ed Braxton    Corporate  San Francisco  California       94122
# 3  Neil Französisch  Home Office   Jacksonville     Florida       32216
# 4   Jasper Cacioppo     Consumer  New York City    New York       10024
#
#   region                                       product name         category  \
# ...

# %%
data.shape
# Out:
# (9792, 16)

# %%
data[['order id', 'order date', 'ship date', 'ship mode', 'sales',
                      'customer id', 'product id', 'city', 'state', 'postal code', 'region']]
# Out:
#             order id order date  ship date       ship mode   sales  \
# 0     CA-2015-100006 2015-09-07 2015-09-13  Standard Class  377.97
# 1     CA-2015-100090 2015-07-08 2015-07-12  Standard Class  502.49
# 2     CA-2015-100090 2015-07-08 2015-07-12  Standard Class  196.70
# 3     CA-2015-100293 2015-03-14 2015-03-18  Standard Class   91.06
# 4     CA-2015-100328 2015-01-28 2015-02-03  Standard Class    3.93
# ...              ...        ...        ...             ...     ...
# 9787  US-2018-169551 2018-07-07 2018-07-09     First Class   15.55
# 9788  US-2018-169551 2018-07-07 2018-07-09     First Class   13.39
# 9789  US-2018-169551 2018-07-07 2018-07-09     First Class   16.78
# 9790  US-2018-169551 2018-07-07 2018-07-09     First Class  527.92
# 9791  US-2018-169551 2018-07-07 2018-07-09     First Class  683.99
#
#      customer id       product id           city         state postal code  \
# 0       DK-13375  TEC-PH-10002075  New York City      New York       10024
# ...

# %%
segment_check = data.groupby('customer id')['segment'].nunique()

# %%
segment_check
# Out:
# customer id
# AA-10315    1
# AA-10375    1
# AA-10480    1
# AA-10645    1
# AB-10015    1
# AB-10060    1
# AB-10105    1
# AB-10150    1
# AB-10165    1
# AB-10255    1
# AB-10600    1
# AC-10420    1
# AC-10450    1
# AC-10615    1
# AC-10660    1
# AD-10180    1
# AF-10870    1
# AF-10885    1
# AG-10270    1
# AG-10300    1
# AG-10330    1
# AG-10390    1
# AG-10495    1
# AG-10525    1
# AG-10675    1
# AG-10765    1
# AG-10900    1
# AH-10030    1
# AH-10075    1
# AH-10120    1
# AH-10195    1
# AH-10210    1
# AH-10465    1
# AH-10585    1
# AH-10690    1
# AI-10855    1
# AJ-10780    1
# AJ-10795    1
# AJ-10945    1
# AJ-10960    1
# AM-10360    1
# AM-10705    1
# AO-10810    1
# AP-10720    1
# AP-10915    1
# AR-10345    1
# AR-10405    1
# AR-10510    1
# AR-10540    1
# AR-10570    1
# AR-10825    1
# AS-10045    1
# AS-10090    1
# AS-10135    1
# AS-10225    1
# AS-10240    1
# AS-10285    1
# AS-10630    1
# AT-10435    1
# AT-10735    1
# AW-10840    1
# ...

# %%
data.head()
# Out:
#          order id       product id customer id order date  ship date  \
# 0  CA-2015-100006  TEC-PH-10002075    DK-13375 2015-09-07 2015-09-13
# 1  CA-2015-100090  FUR-TA-10003715    EB-13705 2015-07-08 2015-07-12
# 2  CA-2015-100090  OFF-BI-10001597    EB-13705 2015-07-08 2015-07-12
# 3  CA-2015-100293  OFF-PA-10000176    NF-18475 2015-03-14 2015-03-18
# 4  CA-2015-100328  OFF-BI-10000343    JC-15340 2015-01-28 2015-02-03
#
#       customer name      segment           city       state postal code  \
# 0       Dennis Kane     Consumer  New York City    New York       10024
# 1        Ed Braxton    Corporate  San Francisco  California       94122
# 2        Ed Braxton    Corporate  San Francisco  California       94122
# 3  Neil Französisch  Home Office   Jacksonville     Florida       32216
# 4   Jasper Cacioppo     Consumer  New York City    New York       10024
#
#   region                                       product name         category  \
# ...

# %%
data[['first name','middle name','last name']]=data['customer name'].str.split(expand=True)

# %%
data.head()
# Out:
#          order id       product id customer id order date  ship date  \
# 0  CA-2015-100006  TEC-PH-10002075    DK-13375 2015-09-07 2015-09-13
# 1  CA-2015-100090  FUR-TA-10003715    EB-13705 2015-07-08 2015-07-12
# 2  CA-2015-100090  OFF-BI-10001597    EB-13705 2015-07-08 2015-07-12
# 3  CA-2015-100293  OFF-PA-10000176    NF-18475 2015-03-14 2015-03-18
# 4  CA-2015-100328  OFF-BI-10000343    JC-15340 2015-01-28 2015-02-03
#
#       customer name      segment           city       state postal code  \
# 0       Dennis Kane     Consumer  New York City    New York       10024
# 1        Ed Braxton    Corporate  San Francisco  California       94122
# 2        Ed Braxton    Corporate  San Francisco  California       94122
# 3  Neil Französisch  Home Office   Jacksonville     Florida       32216
# 4   Jasper Cacioppo     Consumer  New York City    New York       10024
#
#   region                                       product name         category  \
# ...

# %%
data.drop('customer name',axis=1,inplace=True)

# %%
order_details = data[['order id', 'order date', 'ship date', 'ship mode', 'sales',
                      'customer id', 'product id', 'city', 'state', 'postal code', 'region']]

# -----------------------
# 2. Customer Details (Unique per Customer ID)
customer_details = data[['customer id', 'segment','first name','middle name','last name']].drop_duplicates()

# -----------------------
# 3. Product Details (Unique per Product ID)
product_details = data[['product id', 'category', 'sub-category','product name']].drop_duplicates()

# -----------------------
# Save to separate Excel files
order_details.to_excel('order_details.xlsx', index=False)
customer_details.to_excel('customer_details.xlsx', index=False)
product_details.to_excel('product_details.xlsx', index=False)
